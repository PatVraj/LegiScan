# %%
import os
import requests
import time
import logging
import json
import pandas as pd
from datetime import datetime
from openpyxl import load_workbook

# ----------------------------
# Constants
# ----------------------------
VALID_YEARS = {str(year) for year in range(2010, 2025)}

STATE_ABBREVIATIONS = [
    "AL", "AK", "AZ", "AR", "CA", "CO", "CT", "DC", "DE", "FL", "GA", "HI", "ID", "IL", "IN", "IA", "KS", "KY", "LA",
    "ME", "MD", "MA", "MI", "MN", "MS", "MO", "MT", "NE", "NV", "NH", "NJ", "NM", "NY", "NC", "ND", "OH", "OK",
    "OR", "PA", "PR", "RI", "SC", "SD", "TN", "TX", "UT", "VT", "VA", "WA", "WV", "WI", "WY"
]
PREFIXES = ["H", "S", "C"]  # House, Senate, Congress

# ----------------------------
# Logging Configuration
# ----------------------------
logging.basicConfig(
    level=logging.INFO,
    format='%(asctime)s [%(levelname)s] %(message)s',
    handlers=[
        logging.FileHandler("legiscan_api.log"),
        logging.StreamHandler()
    ]
)

# API key and base URL
API_KEY = "c54a2cddb8d0e7b54de012389c3b0fda"
BASE_URL = "https://api.legiscan.com/"

# ----------------------------
# API Cache Setup for Static Data
# ----------------------------
# Since you're retrieving historical data (which is static), cache each API call indefinitely.
CACHE_THRESHOLDS = {
    "getSessionList": float('inf'),
    "getMasterList": float('inf'),
    "getMasterListRaw": float('inf'),
    "getBill": float('inf'),
    "getBillText": float('inf'),
    "getAmendment": float('inf'),
    "getSupplement": float('inf'),
    "getRollcall": float('inf'),
    "getPerson": float('inf'),
    "getSponsoredList": float('inf')
}

# In-memory cache dictionary
# Keys: (operation, frozenset of parameter items)
# Values: dictionary with keys "data" and "timestamp"
api_cache = {}

def cached_api_call(op, params):
    """
    Call the API and cache the response indefinitely.
    """
    key = (op, frozenset(params.items()))
    now = time.time()
    threshold = CACHE_THRESHOLDS.get(op, 0)
    
    if key in api_cache:
        logging.info(f"Using cached response for op {op} with params {params}")
        return api_cache[key]["data"]
    
    # Include API key and op in the parameters
    params.update({"key": API_KEY, "op": op})
    
    while True:
        try:
            response = requests.get(BASE_URL, params=params)
            if response.status_code == 429:
                logging.warning("HTTP 429 Rate limit hit. Sleeping for 60 seconds.")
                time.sleep(60)
                continue
            response.raise_for_status()
            data = response.json()
            if data.get("status") != "OK":
                alert_msg = data.get("alert", {}).get("message", "").lower()
                if "rate" in alert_msg:
                    logging.warning(f"Rate limit alert from API: {alert_msg}. Sleeping for 60 seconds.")
                    time.sleep(60)
                    continue
                logging.error(f"API call failed for op {op} with params {params}: {data}")
                return None
            logging.info(f"Successful API call: op {op}, params {params}")
            api_cache[key] = {"data": data, "timestamp": now}
            return data
        except Exception as e:
            logging.error(f"Exception during API call op {op} with params {params}: {e}")
            logging.warning("Sleeping for 60 seconds before retrying.")
            time.sleep(60)

# ----------------------------
# Excel Appending Helper Function
# ----------------------------
def append_record_to_excel(filename, record):
    """
    Append a single record (dictionary) to an Excel file.
    Nested fields are converted to JSON strings.
    """
    # Convert nested structures to JSON strings if needed
    record_processed = {}
    for key, value in record.items():
        if isinstance(value, (dict, list)):
            record_processed[key] = json.dumps(value)
        else:
            record_processed[key] = value
    df = pd.DataFrame([record_processed])
    
    if not os.path.exists(filename):
        df.to_excel(filename, index=False)
        logging.info(f"Created new Excel file: {filename}")
    else:
        # Append to the existing file
        try:
            with pd.ExcelWriter(filename, mode='a', engine='openpyxl', if_sheet_exists='overlay') as writer:
                # Load the existing workbook and determine the last row in the sheet
                writer.book = load_workbook(filename)
                sheet_name = writer.book.sheetnames[0]
                writer.sheets = {ws.title: ws for ws in writer.book.worksheets}
                startrow = writer.sheets[sheet_name].max_row
                df.to_excel(writer, index=False, header=False, startrow=startrow)
                logging.info(f"Appended record to Excel file: {filename}")
        except Exception as e:
            logging.error(f"Error appending to Excel file {filename}: {e}")

# ----------------------------
# API Operation Functions Using Cache
# ----------------------------
def get_session_list(state):
    data = cached_api_call("getSessionList", {"state": state})
    if data and "sessions" in data:
        logging.info(f"Retrieved {len(data['sessions'])} sessions for state {state}")
        return data["sessions"]
    logging.warning(f"No session data for state {state}")
    return []

def get_master_list(session_id):
    data = cached_api_call("getMasterList", {"id": session_id})
    if data and "masterlist" in data:
        masterlist = data["masterlist"]
        logging.info(f"Session {session_id}: Retrieved master list with {len(masterlist)} bills")
        return list(masterlist.values())
    logging.warning(f"Session {session_id}: No master list data")
    return []

def get_bill_details(bill_id):
    data = cached_api_call("getBill", {"id": bill_id})
    if data and "bill" in data:
        logging.info(f"Bill {bill_id}: Retrieved detailed information")
        return data["bill"]
    logging.warning(f"Bill {bill_id}: No detailed information retrieved")
    return {}

def get_bill_text(doc_id):
    data = cached_api_call("getBillText", {"id": doc_id})
    if data and "text" in data:
        logging.info(f"Retrieved bill text for doc_id {doc_id}")
        return data["text"]
    logging.warning(f"No bill text for doc_id {doc_id}")
    return {}

def get_amendment(amendment_id):
    data = cached_api_call("getAmendment", {"id": amendment_id})
    if data and "amendment" in data:
        logging.info(f"Retrieved amendment for id {amendment_id}")
        return data["amendment"]
    logging.warning(f"No amendment for id {amendment_id}")
    return {}

def get_supplement(supplement_id):
    data = cached_api_call("getSupplement", {"id": supplement_id})
    if data and "supplement" in data:
        logging.info(f"Retrieved supplement for id {supplement_id}")
        return data["supplement"]
    logging.warning(f"No supplement for id {supplement_id}")
    return {}

def get_roll_call(roll_call_id):
    data = cached_api_call("getRollcall", {"id": roll_call_id})
    if data and "roll_call" in data:
        logging.info(f"Retrieved roll call for id {roll_call_id}")
        return data["roll_call"]
    logging.warning(f"No roll call for id {roll_call_id}")
    return {}

def get_person(people_id):
    data = cached_api_call("getPerson", {"id": people_id})
    if data and "person" in data:
        logging.info(f"Retrieved person data for id {people_id}")
        return data["person"]
    logging.warning(f"No person data for id {people_id}")
    return {}

def get_sponsored_list(people_id):
    data = cached_api_call("getSponsoredList", {"id": people_id})
    if data and "sponsoredbills" in data:
        logging.info(f"Retrieved sponsored bills for person id {people_id}")
        return data["sponsoredbills"]
    logging.warning(f"No sponsored bills for person id {people_id}")
    return {}

# ----------------------------
# Checkpoint Functions
# ----------------------------
CHECKPOINT_FILE = "checkpoint.json"

def save_checkpoint(year, state, session_idx, bill_idx):
    checkpoint = {
        "year": year,
        "state": state,
        "session_idx": session_idx,
        "bill_idx": bill_idx
    }
    with open(CHECKPOINT_FILE, "w") as f:
        json.dump(checkpoint, f)
    logging.info(f"Checkpoint saved: {checkpoint}")

def load_checkpoint():
    try:
        with open(CHECKPOINT_FILE, "r") as f:
            checkpoint = json.load(f)
        logging.info(f"Checkpoint loaded: {checkpoint}")
        return checkpoint
    except Exception:
        logging.info("No checkpoint found, starting fresh.")
        return None

# ----------------------------
# Process a Single State for a Given Year
# ----------------------------
def process_state_year(year, state, checkpoint=None):
    filename = f"legiscan_{state}_{year}.xlsx"
    logging.info(f"--- Starting processing for {state} for year {year} ---")
    sessions = get_session_list(state)
    # Filter sessions by year using session_name or year boundaries
    year_sessions = [s for s in sessions if str(year) in str(s.get("session_name", "")) or 
                     (s.get("year_start") and s.get("year_start") <= year <= s.get("year_end", year))]
    logging.info(f"State {state}: Found {len(year_sessions)} sessions for year {year}")
    
    for sess_idx, session in enumerate(year_sessions):
        # Resume checkpoint if applicable
        if checkpoint and checkpoint.get("year") == year and checkpoint.get("state") == state:
            if sess_idx < checkpoint.get("session_idx", 0):
                continue
            bill_resume = checkpoint.get("bill_idx", 0) if sess_idx == checkpoint.get("session_idx", 0) else 0
        else:
            bill_resume = 0

        session_id = session.get("session_id")
        logging.info(f"State {state}, Session {session_id}: Retrieving master list")
        master_list = get_master_list(session_id)
        for bill_idx, bill_summary in enumerate(master_list):
            if bill_idx < bill_resume:
                continue

            bill_id = bill_summary.get("bill_id")
            bill_details = get_bill_details(bill_id)
            if not bill_details:
                logging.warning(f"Skipping bill {bill_id} due to missing details.")
                continue

            # Combine summary and detailed info into a single record
            record = {**bill_summary, **bill_details}
            record["state"] = state
            record["year"] = year

            # Retrieve full bill text if available
            if bill_details.get("doc_id"):
                record["bill_text"] = get_bill_text(bill_details["doc_id"])
            else:
                record["bill_text"] = {}

            # Retrieve amendments (if referenced)
            amendments = bill_details.get("amendments", [])
            record["amendments"] = [get_amendment(amendment.get("amendment_id")) 
                                    for amendment in amendments if amendment.get("amendment_id")]

            # Retrieve supplements (if referenced)
            supplements = bill_details.get("supplements", [])
            record["supplements"] = [get_supplement(supplement.get("supplement_id"))
                                     for supplement in supplements if supplement.get("supplement_id")]

            # Retrieve roll call details if available
            if bill_details.get("roll_call_id"):
                record["roll_call"] = get_roll_call(bill_details["roll_call_id"])
            else:
                record["roll_call"] = {}

            # Retrieve detailed sponsor info and sponsored bills
            sponsors = bill_details.get("sponsors", [])
            detailed_sponsors = []
            for sponsor in sponsors:
                people_id = sponsor.get("people_id")
                if people_id:
                    person_data = get_person(people_id)
                    sponsored_bills = get_sponsored_list(people_id)
                    sponsor_record = {**sponsor, "person_details": person_data, "sponsored_bills": sponsored_bills}
                    detailed_sponsors.append(sponsor_record)
            record["sponsors"] = detailed_sponsors

            # Append the processed record to the Excel file immediately
            append_record_to_excel(filename, record)

            logging.info(f"Stored bill {bill_id} - {record.get('number')} - {record.get('title')}")
            # Save checkpoint after each bill processed
            save_checkpoint(year, state, sess_idx, bill_idx)
            
    logging.info(f"--- Completed processing for {state} for year {year} ---")

# ----------------------------
# Main Function: Process Each State per Year
# ----------------------------
def main():
    checkpoint = load_checkpoint()
    for year in range(2024, 2009, -1):
        for state in STATE_ABBREVIATIONS:
            logging.info(f"=== Processing {state} for year {year} ===")
            process_state_year(year, state, checkpoint=checkpoint)
            # Reset checkpoint for next state/year combination
            checkpoint = None

if __name__ == "__main__":
    main()
# Out:
# 2025-03-12 16:44:37,687 [INFO] Checkpoint loaded: {'year': 2024, 'state': 'AZ', 'session_idx': 0, 'bill_idx': 994}
# 2025-03-12 16:44:37,689 [INFO] === Processing AL for year 2024 ===
# 2025-03-12 16:44:37,690 [INFO] --- Starting processing for AL for year 2024 ---
# 2025-03-12 16:44:37,940 [ERROR] API call failed for op getSessionList with params {'state': 'AL', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:37,943 [WARNING] No session data for state AL
# 2025-03-12 16:44:37,943 [INFO] State AL: Found 0 sessions for year 2024
# 2025-03-12 16:44:37,944 [INFO] --- Completed processing for AL for year 2024 ---
# 2025-03-12 16:44:37,945 [INFO] === Processing AK for year 2024 ===
# 2025-03-12 16:44:37,945 [INFO] --- Starting processing for AK for year 2024 ---
# 2025-03-12 16:44:38,141 [ERROR] API call failed for op getSessionList with params {'state': 'AK', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,142 [WARNING] No session data for state AK
# 2025-03-12 16:44:38,143 [INFO] State AK: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,144 [INFO] --- Completed processing for AK for year 2024 ---
# 2025-03-12 16:44:38,145 [INFO] === Processing AZ for year 2024 ===
# 2025-03-12 16:44:38,146 [INFO] --- Starting processing for AZ for year 2024 ---
# 2025-03-12 16:44:38,273 [ERROR] API call failed for op getSessionList with params {'state': 'AZ', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,275 [WARNING] No session data for state AZ
# 2025-03-12 16:44:38,276 [INFO] State AZ: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,277 [INFO] --- Completed processing for AZ for year 2024 ---
# 2025-03-12 16:44:38,278 [INFO] === Processing AR for year 2024 ===
# 2025-03-12 16:44:38,278 [INFO] --- Starting processing for AR for year 2024 ---
# 2025-03-12 16:44:38,403 [ERROR] API call failed for op getSessionList with params {'state': 'AR', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,404 [WARNING] No session data for state AR
# 2025-03-12 16:44:38,405 [INFO] State AR: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,406 [INFO] --- Completed processing for AR for year 2024 ---
# 2025-03-12 16:44:38,407 [INFO] === Processing CA for year 2024 ===
# 2025-03-12 16:44:38,407 [INFO] --- Starting processing for CA for year 2024 ---
# 2025-03-12 16:44:38,531 [ERROR] API call failed for op getSessionList with params {'state': 'CA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,532 [WARNING] No session data for state CA
# 2025-03-12 16:44:38,532 [INFO] State CA: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,533 [INFO] --- Completed processing for CA for year 2024 ---
# 2025-03-12 16:44:38,534 [INFO] === Processing CO for year 2024 ===
# 2025-03-12 16:44:38,534 [INFO] --- Starting processing for CO for year 2024 ---
# 2025-03-12 16:44:38,653 [ERROR] API call failed for op getSessionList with params {'state': 'CO', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,654 [WARNING] No session data for state CO
# 2025-03-12 16:44:38,655 [INFO] State CO: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,655 [INFO] --- Completed processing for CO for year 2024 ---
# 2025-03-12 16:44:38,656 [INFO] === Processing CT for year 2024 ===
# 2025-03-12 16:44:38,656 [INFO] --- Starting processing for CT for year 2024 ---
# 2025-03-12 16:44:38,774 [ERROR] API call failed for op getSessionList with params {'state': 'CT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,775 [WARNING] No session data for state CT
# 2025-03-12 16:44:38,776 [INFO] State CT: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,776 [INFO] --- Completed processing for CT for year 2024 ---
# 2025-03-12 16:44:38,777 [INFO] === Processing DC for year 2024 ===
# 2025-03-12 16:44:38,778 [INFO] --- Starting processing for DC for year 2024 ---
# 2025-03-12 16:44:38,895 [ERROR] API call failed for op getSessionList with params {'state': 'DC', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:38,897 [WARNING] No session data for state DC
# 2025-03-12 16:44:38,897 [INFO] State DC: Found 0 sessions for year 2024
# 2025-03-12 16:44:38,898 [INFO] --- Completed processing for DC for year 2024 ---
# 2025-03-12 16:44:38,900 [INFO] === Processing DE for year 2024 ===
# 2025-03-12 16:44:38,901 [INFO] --- Starting processing for DE for year 2024 ---
# 2025-03-12 16:44:39,026 [ERROR] API call failed for op getSessionList with params {'state': 'DE', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,028 [WARNING] No session data for state DE
# 2025-03-12 16:44:39,029 [INFO] State DE: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,030 [INFO] --- Completed processing for DE for year 2024 ---
# 2025-03-12 16:44:39,031 [INFO] === Processing FL for year 2024 ===
# 2025-03-12 16:44:39,032 [INFO] --- Starting processing for FL for year 2024 ---
# 2025-03-12 16:44:39,156 [ERROR] API call failed for op getSessionList with params {'state': 'FL', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,158 [WARNING] No session data for state FL
# 2025-03-12 16:44:39,159 [INFO] State FL: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,160 [INFO] --- Completed processing for FL for year 2024 ---
# 2025-03-12 16:44:39,161 [INFO] === Processing GA for year 2024 ===
# 2025-03-12 16:44:39,164 [INFO] --- Starting processing for GA for year 2024 ---
# 2025-03-12 16:44:39,291 [ERROR] API call failed for op getSessionList with params {'state': 'GA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,292 [WARNING] No session data for state GA
# 2025-03-12 16:44:39,293 [INFO] State GA: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,294 [INFO] --- Completed processing for GA for year 2024 ---
# 2025-03-12 16:44:39,295 [INFO] === Processing HI for year 2024 ===
# 2025-03-12 16:44:39,295 [INFO] --- Starting processing for HI for year 2024 ---
# 2025-03-12 16:44:39,419 [ERROR] API call failed for op getSessionList with params {'state': 'HI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,420 [WARNING] No session data for state HI
# 2025-03-12 16:44:39,421 [INFO] State HI: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,422 [INFO] --- Completed processing for HI for year 2024 ---
# 2025-03-12 16:44:39,424 [INFO] === Processing ID for year 2024 ===
# 2025-03-12 16:44:39,427 [INFO] --- Starting processing for ID for year 2024 ---
# 2025-03-12 16:44:39,550 [ERROR] API call failed for op getSessionList with params {'state': 'ID', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,551 [WARNING] No session data for state ID
# 2025-03-12 16:44:39,551 [INFO] State ID: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,552 [INFO] --- Completed processing for ID for year 2024 ---
# 2025-03-12 16:44:39,553 [INFO] === Processing IL for year 2024 ===
# 2025-03-12 16:44:39,553 [INFO] --- Starting processing for IL for year 2024 ---
# 2025-03-12 16:44:39,670 [ERROR] API call failed for op getSessionList with params {'state': 'IL', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,672 [WARNING] No session data for state IL
# 2025-03-12 16:44:39,673 [INFO] State IL: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,673 [INFO] --- Completed processing for IL for year 2024 ---
# 2025-03-12 16:44:39,674 [INFO] === Processing IN for year 2024 ===
# 2025-03-12 16:44:39,674 [INFO] --- Starting processing for IN for year 2024 ---
# 2025-03-12 16:44:39,801 [ERROR] API call failed for op getSessionList with params {'state': 'IN', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,802 [WARNING] No session data for state IN
# 2025-03-12 16:44:39,802 [INFO] State IN: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,803 [INFO] --- Completed processing for IN for year 2024 ---
# 2025-03-12 16:44:39,804 [INFO] === Processing IA for year 2024 ===
# 2025-03-12 16:44:39,805 [INFO] --- Starting processing for IA for year 2024 ---
# 2025-03-12 16:44:39,926 [ERROR] API call failed for op getSessionList with params {'state': 'IA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:39,927 [WARNING] No session data for state IA
# 2025-03-12 16:44:39,928 [INFO] State IA: Found 0 sessions for year 2024
# 2025-03-12 16:44:39,928 [INFO] --- Completed processing for IA for year 2024 ---
# 2025-03-12 16:44:39,929 [INFO] === Processing KS for year 2024 ===
# 2025-03-12 16:44:39,930 [INFO] --- Starting processing for KS for year 2024 ---
# 2025-03-12 16:44:40,051 [ERROR] API call failed for op getSessionList with params {'state': 'KS', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,052 [WARNING] No session data for state KS
# 2025-03-12 16:44:40,053 [INFO] State KS: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,054 [INFO] --- Completed processing for KS for year 2024 ---
# 2025-03-12 16:44:40,056 [INFO] === Processing KY for year 2024 ===
# 2025-03-12 16:44:40,057 [INFO] --- Starting processing for KY for year 2024 ---
# 2025-03-12 16:44:40,183 [ERROR] API call failed for op getSessionList with params {'state': 'KY', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,184 [WARNING] No session data for state KY
# 2025-03-12 16:44:40,185 [INFO] State KY: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,186 [INFO] --- Completed processing for KY for year 2024 ---
# 2025-03-12 16:44:40,187 [INFO] === Processing LA for year 2024 ===
# 2025-03-12 16:44:40,188 [INFO] --- Starting processing for LA for year 2024 ---
# 2025-03-12 16:44:40,311 [ERROR] API call failed for op getSessionList with params {'state': 'LA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,312 [WARNING] No session data for state LA
# 2025-03-12 16:44:40,313 [INFO] State LA: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,314 [INFO] --- Completed processing for LA for year 2024 ---
# 2025-03-12 16:44:40,315 [INFO] === Processing ME for year 2024 ===
# 2025-03-12 16:44:40,316 [INFO] --- Starting processing for ME for year 2024 ---
# 2025-03-12 16:44:40,441 [ERROR] API call failed for op getSessionList with params {'state': 'ME', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,442 [WARNING] No session data for state ME
# 2025-03-12 16:44:40,443 [INFO] State ME: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,443 [INFO] --- Completed processing for ME for year 2024 ---
# 2025-03-12 16:44:40,444 [INFO] === Processing MD for year 2024 ===
# 2025-03-12 16:44:40,446 [INFO] --- Starting processing for MD for year 2024 ---
# 2025-03-12 16:44:40,568 [ERROR] API call failed for op getSessionList with params {'state': 'MD', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,569 [WARNING] No session data for state MD
# 2025-03-12 16:44:40,570 [INFO] State MD: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,571 [INFO] --- Completed processing for MD for year 2024 ---
# 2025-03-12 16:44:40,573 [INFO] === Processing MA for year 2024 ===
# 2025-03-12 16:44:40,574 [INFO] --- Starting processing for MA for year 2024 ---
# 2025-03-12 16:44:40,703 [ERROR] API call failed for op getSessionList with params {'state': 'MA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,705 [WARNING] No session data for state MA
# 2025-03-12 16:44:40,706 [INFO] State MA: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,708 [INFO] --- Completed processing for MA for year 2024 ---
# 2025-03-12 16:44:40,708 [INFO] === Processing MI for year 2024 ===
# 2025-03-12 16:44:40,709 [INFO] --- Starting processing for MI for year 2024 ---
# 2025-03-12 16:44:40,829 [ERROR] API call failed for op getSessionList with params {'state': 'MI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,830 [WARNING] No session data for state MI
# 2025-03-12 16:44:40,831 [INFO] State MI: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,832 [INFO] --- Completed processing for MI for year 2024 ---
# 2025-03-12 16:44:40,833 [INFO] === Processing MN for year 2024 ===
# 2025-03-12 16:44:40,834 [INFO] --- Starting processing for MN for year 2024 ---
# 2025-03-12 16:44:40,962 [ERROR] API call failed for op getSessionList with params {'state': 'MN', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:40,964 [WARNING] No session data for state MN
# 2025-03-12 16:44:40,964 [INFO] State MN: Found 0 sessions for year 2024
# 2025-03-12 16:44:40,966 [INFO] --- Completed processing for MN for year 2024 ---
# 2025-03-12 16:44:40,967 [INFO] === Processing MS for year 2024 ===
# 2025-03-12 16:44:40,968 [INFO] --- Starting processing for MS for year 2024 ---
# 2025-03-12 16:44:41,092 [ERROR] API call failed for op getSessionList with params {'state': 'MS', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,093 [WARNING] No session data for state MS
# 2025-03-12 16:44:41,094 [INFO] State MS: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,094 [INFO] --- Completed processing for MS for year 2024 ---
# 2025-03-12 16:44:41,095 [INFO] === Processing MO for year 2024 ===
# 2025-03-12 16:44:41,096 [INFO] --- Starting processing for MO for year 2024 ---
# 2025-03-12 16:44:41,221 [ERROR] API call failed for op getSessionList with params {'state': 'MO', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,224 [WARNING] No session data for state MO
# 2025-03-12 16:44:41,225 [INFO] State MO: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,227 [INFO] --- Completed processing for MO for year 2024 ---
# 2025-03-12 16:44:41,228 [INFO] === Processing MT for year 2024 ===
# 2025-03-12 16:44:41,229 [INFO] --- Starting processing for MT for year 2024 ---
# 2025-03-12 16:44:41,357 [ERROR] API call failed for op getSessionList with params {'state': 'MT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,359 [WARNING] No session data for state MT
# 2025-03-12 16:44:41,360 [INFO] State MT: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,362 [INFO] --- Completed processing for MT for year 2024 ---
# 2025-03-12 16:44:41,363 [INFO] === Processing NE for year 2024 ===
# 2025-03-12 16:44:41,365 [INFO] --- Starting processing for NE for year 2024 ---
# 2025-03-12 16:44:41,494 [ERROR] API call failed for op getSessionList with params {'state': 'NE', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,496 [WARNING] No session data for state NE
# 2025-03-12 16:44:41,497 [INFO] State NE: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,499 [INFO] --- Completed processing for NE for year 2024 ---
# 2025-03-12 16:44:41,500 [INFO] === Processing NV for year 2024 ===
# 2025-03-12 16:44:41,502 [INFO] --- Starting processing for NV for year 2024 ---
# 2025-03-12 16:44:41,625 [ERROR] API call failed for op getSessionList with params {'state': 'NV', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,626 [WARNING] No session data for state NV
# 2025-03-12 16:44:41,627 [INFO] State NV: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,628 [INFO] --- Completed processing for NV for year 2024 ---
# 2025-03-12 16:44:41,629 [INFO] === Processing NH for year 2024 ===
# 2025-03-12 16:44:41,630 [INFO] --- Starting processing for NH for year 2024 ---
# 2025-03-12 16:44:41,760 [ERROR] API call failed for op getSessionList with params {'state': 'NH', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,761 [WARNING] No session data for state NH
# 2025-03-12 16:44:41,761 [INFO] State NH: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,762 [INFO] --- Completed processing for NH for year 2024 ---
# 2025-03-12 16:44:41,763 [INFO] === Processing NJ for year 2024 ===
# 2025-03-12 16:44:41,763 [INFO] --- Starting processing for NJ for year 2024 ---
# 2025-03-12 16:44:41,884 [ERROR] API call failed for op getSessionList with params {'state': 'NJ', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:41,885 [WARNING] No session data for state NJ
# 2025-03-12 16:44:41,886 [INFO] State NJ: Found 0 sessions for year 2024
# 2025-03-12 16:44:41,887 [INFO] --- Completed processing for NJ for year 2024 ---
# 2025-03-12 16:44:41,888 [INFO] === Processing NM for year 2024 ===
# 2025-03-12 16:44:41,888 [INFO] --- Starting processing for NM for year 2024 ---
# 2025-03-12 16:44:42,008 [ERROR] API call failed for op getSessionList with params {'state': 'NM', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,009 [WARNING] No session data for state NM
# 2025-03-12 16:44:42,010 [INFO] State NM: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,011 [INFO] --- Completed processing for NM for year 2024 ---
# 2025-03-12 16:44:42,012 [INFO] === Processing NY for year 2024 ===
# 2025-03-12 16:44:42,013 [INFO] --- Starting processing for NY for year 2024 ---
# 2025-03-12 16:44:42,138 [ERROR] API call failed for op getSessionList with params {'state': 'NY', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,139 [WARNING] No session data for state NY
# 2025-03-12 16:44:42,140 [INFO] State NY: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,141 [INFO] --- Completed processing for NY for year 2024 ---
# 2025-03-12 16:44:42,142 [INFO] === Processing NC for year 2024 ===
# 2025-03-12 16:44:42,143 [INFO] --- Starting processing for NC for year 2024 ---
# 2025-03-12 16:44:42,265 [ERROR] API call failed for op getSessionList with params {'state': 'NC', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,267 [WARNING] No session data for state NC
# 2025-03-12 16:44:42,268 [INFO] State NC: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,269 [INFO] --- Completed processing for NC for year 2024 ---
# 2025-03-12 16:44:42,270 [INFO] === Processing ND for year 2024 ===
# 2025-03-12 16:44:42,271 [INFO] --- Starting processing for ND for year 2024 ---
# 2025-03-12 16:44:42,393 [ERROR] API call failed for op getSessionList with params {'state': 'ND', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,395 [WARNING] No session data for state ND
# 2025-03-12 16:44:42,397 [INFO] State ND: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,399 [INFO] --- Completed processing for ND for year 2024 ---
# 2025-03-12 16:44:42,400 [INFO] === Processing OH for year 2024 ===
# 2025-03-12 16:44:42,401 [INFO] --- Starting processing for OH for year 2024 ---
# 2025-03-12 16:44:42,524 [ERROR] API call failed for op getSessionList with params {'state': 'OH', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,526 [WARNING] No session data for state OH
# 2025-03-12 16:44:42,527 [INFO] State OH: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,528 [INFO] --- Completed processing for OH for year 2024 ---
# 2025-03-12 16:44:42,529 [INFO] === Processing OK for year 2024 ===
# 2025-03-12 16:44:42,530 [INFO] --- Starting processing for OK for year 2024 ---
# 2025-03-12 16:44:42,650 [ERROR] API call failed for op getSessionList with params {'state': 'OK', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,652 [WARNING] No session data for state OK
# 2025-03-12 16:44:42,653 [INFO] State OK: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,656 [INFO] --- Completed processing for OK for year 2024 ---
# 2025-03-12 16:44:42,657 [INFO] === Processing OR for year 2024 ===
# 2025-03-12 16:44:42,659 [INFO] --- Starting processing for OR for year 2024 ---
# 2025-03-12 16:44:42,779 [ERROR] API call failed for op getSessionList with params {'state': 'OR', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,781 [WARNING] No session data for state OR
# 2025-03-12 16:44:42,782 [INFO] State OR: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,783 [INFO] --- Completed processing for OR for year 2024 ---
# 2025-03-12 16:44:42,784 [INFO] === Processing PA for year 2024 ===
# 2025-03-12 16:44:42,785 [INFO] --- Starting processing for PA for year 2024 ---
# 2025-03-12 16:44:42,912 [ERROR] API call failed for op getSessionList with params {'state': 'PA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:42,913 [WARNING] No session data for state PA
# 2025-03-12 16:44:42,914 [INFO] State PA: Found 0 sessions for year 2024
# 2025-03-12 16:44:42,915 [INFO] --- Completed processing for PA for year 2024 ---
# 2025-03-12 16:44:42,916 [INFO] === Processing PR for year 2024 ===
# 2025-03-12 16:44:42,916 [INFO] --- Starting processing for PR for year 2024 ---
# 2025-03-12 16:44:43,040 [ERROR] API call failed for op getSessionList with params {'state': 'PR', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,041 [WARNING] No session data for state PR
# 2025-03-12 16:44:43,041 [INFO] State PR: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,043 [INFO] --- Completed processing for PR for year 2024 ---
# 2025-03-12 16:44:43,044 [INFO] === Processing RI for year 2024 ===
# 2025-03-12 16:44:43,044 [INFO] --- Starting processing for RI for year 2024 ---
# 2025-03-12 16:44:43,167 [ERROR] API call failed for op getSessionList with params {'state': 'RI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,169 [WARNING] No session data for state RI
# 2025-03-12 16:44:43,170 [INFO] State RI: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,172 [INFO] --- Completed processing for RI for year 2024 ---
# 2025-03-12 16:44:43,174 [INFO] === Processing SC for year 2024 ===
# 2025-03-12 16:44:43,175 [INFO] --- Starting processing for SC for year 2024 ---
# 2025-03-12 16:44:43,300 [ERROR] API call failed for op getSessionList with params {'state': 'SC', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,302 [WARNING] No session data for state SC
# 2025-03-12 16:44:43,303 [INFO] State SC: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,306 [INFO] --- Completed processing for SC for year 2024 ---
# 2025-03-12 16:44:43,307 [INFO] === Processing SD for year 2024 ===
# 2025-03-12 16:44:43,308 [INFO] --- Starting processing for SD for year 2024 ---
# 2025-03-12 16:44:43,437 [ERROR] API call failed for op getSessionList with params {'state': 'SD', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,440 [WARNING] No session data for state SD
# 2025-03-12 16:44:43,441 [INFO] State SD: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,443 [INFO] --- Completed processing for SD for year 2024 ---
# 2025-03-12 16:44:43,443 [INFO] === Processing TN for year 2024 ===
# 2025-03-12 16:44:43,444 [INFO] --- Starting processing for TN for year 2024 ---
# 2025-03-12 16:44:43,571 [ERROR] API call failed for op getSessionList with params {'state': 'TN', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,573 [WARNING] No session data for state TN
# 2025-03-12 16:44:43,573 [INFO] State TN: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,574 [INFO] --- Completed processing for TN for year 2024 ---
# 2025-03-12 16:44:43,574 [INFO] === Processing TX for year 2024 ===
# 2025-03-12 16:44:43,576 [INFO] --- Starting processing for TX for year 2024 ---
# 2025-03-12 16:44:43,691 [ERROR] API call failed for op getSessionList with params {'state': 'TX', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,692 [WARNING] No session data for state TX
# 2025-03-12 16:44:43,693 [INFO] State TX: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,693 [INFO] --- Completed processing for TX for year 2024 ---
# 2025-03-12 16:44:43,694 [INFO] === Processing UT for year 2024 ===
# 2025-03-12 16:44:43,694 [INFO] --- Starting processing for UT for year 2024 ---
# 2025-03-12 16:44:43,814 [ERROR] API call failed for op getSessionList with params {'state': 'UT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,814 [WARNING] No session data for state UT
# 2025-03-12 16:44:43,815 [INFO] State UT: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,816 [INFO] --- Completed processing for UT for year 2024 ---
# 2025-03-12 16:44:43,817 [INFO] === Processing VT for year 2024 ===
# 2025-03-12 16:44:43,817 [INFO] --- Starting processing for VT for year 2024 ---
# 2025-03-12 16:44:43,936 [ERROR] API call failed for op getSessionList with params {'state': 'VT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:43,937 [WARNING] No session data for state VT
# 2025-03-12 16:44:43,937 [INFO] State VT: Found 0 sessions for year 2024
# 2025-03-12 16:44:43,938 [INFO] --- Completed processing for VT for year 2024 ---
# 2025-03-12 16:44:43,939 [INFO] === Processing VA for year 2024 ===
# 2025-03-12 16:44:43,939 [INFO] --- Starting processing for VA for year 2024 ---
# 2025-03-12 16:44:44,064 [ERROR] API call failed for op getSessionList with params {'state': 'VA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,064 [WARNING] No session data for state VA
# 2025-03-12 16:44:44,065 [INFO] State VA: Found 0 sessions for year 2024
# 2025-03-12 16:44:44,066 [INFO] --- Completed processing for VA for year 2024 ---
# 2025-03-12 16:44:44,066 [INFO] === Processing WA for year 2024 ===
# 2025-03-12 16:44:44,067 [INFO] --- Starting processing for WA for year 2024 ---
# 2025-03-12 16:44:44,188 [ERROR] API call failed for op getSessionList with params {'state': 'WA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,189 [WARNING] No session data for state WA
# 2025-03-12 16:44:44,189 [INFO] State WA: Found 0 sessions for year 2024
# 2025-03-12 16:44:44,190 [INFO] --- Completed processing for WA for year 2024 ---
# 2025-03-12 16:44:44,191 [INFO] === Processing WV for year 2024 ===
# 2025-03-12 16:44:44,192 [INFO] --- Starting processing for WV for year 2024 ---
# 2025-03-12 16:44:44,314 [ERROR] API call failed for op getSessionList with params {'state': 'WV', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,315 [WARNING] No session data for state WV
# 2025-03-12 16:44:44,316 [INFO] State WV: Found 0 sessions for year 2024
# 2025-03-12 16:44:44,317 [INFO] --- Completed processing for WV for year 2024 ---
# 2025-03-12 16:44:44,319 [INFO] === Processing WI for year 2024 ===
# 2025-03-12 16:44:44,320 [INFO] --- Starting processing for WI for year 2024 ---
# 2025-03-12 16:44:44,447 [ERROR] API call failed for op getSessionList with params {'state': 'WI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,449 [WARNING] No session data for state WI
# 2025-03-12 16:44:44,450 [INFO] State WI: Found 0 sessions for year 2024
# 2025-03-12 16:44:44,451 [INFO] --- Completed processing for WI for year 2024 ---
# 2025-03-12 16:44:44,452 [INFO] === Processing WY for year 2024 ===
# 2025-03-12 16:44:44,454 [INFO] --- Starting processing for WY for year 2024 ---
# 2025-03-12 16:44:44,615 [ERROR] API call failed for op getSessionList with params {'state': 'WY', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,616 [WARNING] No session data for state WY
# 2025-03-12 16:44:44,617 [INFO] State WY: Found 0 sessions for year 2024
# 2025-03-12 16:44:44,618 [INFO] --- Completed processing for WY for year 2024 ---
# 2025-03-12 16:44:44,620 [INFO] === Processing AL for year 2023 ===
# 2025-03-12 16:44:44,621 [INFO] --- Starting processing for AL for year 2023 ---
# 2025-03-12 16:44:44,745 [ERROR] API call failed for op getSessionList with params {'state': 'AL', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,746 [WARNING] No session data for state AL
# 2025-03-12 16:44:44,747 [INFO] State AL: Found 0 sessions for year 2023
# 2025-03-12 16:44:44,748 [INFO] --- Completed processing for AL for year 2023 ---
# 2025-03-12 16:44:44,749 [INFO] === Processing AK for year 2023 ===
# 2025-03-12 16:44:44,750 [INFO] --- Starting processing for AK for year 2023 ---
# 2025-03-12 16:44:44,871 [ERROR] API call failed for op getSessionList with params {'state': 'AK', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:44,872 [WARNING] No session data for state AK
# 2025-03-12 16:44:44,873 [INFO] State AK: Found 0 sessions for year 2023
# 2025-03-12 16:44:44,874 [INFO] --- Completed processing for AK for year 2023 ---
# 2025-03-12 16:44:44,876 [INFO] === Processing AZ for year 2023 ===
# 2025-03-12 16:44:44,877 [INFO] --- Starting processing for AZ for year 2023 ---
# 2025-03-12 16:44:45,012 [ERROR] API call failed for op getSessionList with params {'state': 'AZ', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:45,013 [WARNING] No session data for state AZ
# 2025-03-12 16:44:45,013 [INFO] State AZ: Found 0 sessions for year 2023
# 2025-03-12 16:44:45,014 [INFO] --- Completed processing for AZ for year 2023 ---
# 2025-03-12 16:44:45,014 [INFO] === Processing AR for year 2023 ===
# 2025-03-12 16:44:45,015 [INFO] --- Starting processing for AR for year 2023 ---
# 2025-03-12 16:44:45,139 [ERROR] API call failed for op getSessionList with params {'state': 'AR', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:45,140 [WARNING] No session data for state AR
# 2025-03-12 16:44:45,140 [INFO] State AR: Found 0 sessions for year 2023
# 2025-03-12 16:44:45,141 [INFO] --- Completed processing for AR for year 2023 ---
# 2025-03-12 16:44:45,142 [INFO] === Processing CA for year 2023 ===
# 2025-03-12 16:44:45,142 [INFO] --- Starting processing for CA for year 2023 ---
# 2025-03-12 16:44:45,265 [ERROR] API call failed for op getSessionList with params {'state': 'CA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:45,266 [WARNING] No session data for state CA
# 2025-03-12 16:44:45,267 [INFO] State CA: Found 0 sessions for year 2023
# 2025-03-12 16:44:45,268 [INFO] --- Completed processing for CA for year 2023 ---
# 2025-03-12 16:44:45,268 [INFO] === Processing CO for year 2023 ===
# 2025-03-12 16:44:45,269 [INFO] --- Starting processing for CO for year 2023 ---
# 2025-03-12 16:44:45,394 [ERROR] API call failed for op getSessionList with params {'state': 'CO', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:45,395 [WARNING] No session data for state CO
# 2025-03-12 16:44:45,396 [INFO] State CO: Found 0 sessions for year 2023
# 2025-03-12 16:44:45,397 [INFO] --- Completed processing for CO for year 2023 ---
# 2025-03-12 16:44:45,398 [INFO] === Processing CT for year 2023 ===
# 2025-03-12 16:44:45,399 [INFO] --- Starting processing for CT for year 2023 ---
# ...
# 2025-03-12 16:44:49,727 [ERROR] API call failed for op getSessionList with params {'state': 'PA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:49,729 [WARNING] No session data for state PA
# 2025-03-12 16:44:49,730 [INFO] State PA: Found 0 sessions for year 2023
# 2025-03-12 16:44:49,732 [INFO] --- Completed processing for PA for year 2023 ---
# 2025-03-12 16:44:49,733 [INFO] === Processing PR for year 2023 ===
# 2025-03-12 16:44:49,734 [INFO] --- Starting processing for PR for year 2023 ---
# 2025-03-12 16:44:49,859 [ERROR] API call failed for op getSessionList with params {'state': 'PR', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:49,861 [WARNING] No session data for state PR
# 2025-03-12 16:44:49,862 [INFO] State PR: Found 0 sessions for year 2023
# 2025-03-12 16:44:49,865 [INFO] --- Completed processing for PR for year 2023 ---
# 2025-03-12 16:44:49,866 [INFO] === Processing RI for year 2023 ===
# 2025-03-12 16:44:49,867 [INFO] --- Starting processing for RI for year 2023 ---
# 2025-03-12 16:44:49,993 [ERROR] API call failed for op getSessionList with params {'state': 'RI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:49,993 [WARNING] No session data for state RI
# 2025-03-12 16:44:49,994 [INFO] State RI: Found 0 sessions for year 2023
# 2025-03-12 16:44:49,994 [INFO] --- Completed processing for RI for year 2023 ---
# 2025-03-12 16:44:49,995 [INFO] === Processing SC for year 2023 ===
# 2025-03-12 16:44:49,996 [INFO] --- Starting processing for SC for year 2023 ---
# 2025-03-12 16:44:50,117 [ERROR] API call failed for op getSessionList with params {'state': 'SC', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,118 [WARNING] No session data for state SC
# 2025-03-12 16:44:50,118 [INFO] State SC: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,119 [INFO] --- Completed processing for SC for year 2023 ---
# 2025-03-12 16:44:50,119 [INFO] === Processing SD for year 2023 ===
# 2025-03-12 16:44:50,120 [INFO] --- Starting processing for SD for year 2023 ---
# 2025-03-12 16:44:50,239 [ERROR] API call failed for op getSessionList with params {'state': 'SD', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,240 [WARNING] No session data for state SD
# 2025-03-12 16:44:50,240 [INFO] State SD: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,241 [INFO] --- Completed processing for SD for year 2023 ---
# 2025-03-12 16:44:50,242 [INFO] === Processing TN for year 2023 ===
# 2025-03-12 16:44:50,243 [INFO] --- Starting processing for TN for year 2023 ---
# 2025-03-12 16:44:50,360 [ERROR] API call failed for op getSessionList with params {'state': 'TN', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,361 [WARNING] No session data for state TN
# 2025-03-12 16:44:50,361 [INFO] State TN: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,362 [INFO] --- Completed processing for TN for year 2023 ---
# 2025-03-12 16:44:50,363 [INFO] === Processing TX for year 2023 ===
# 2025-03-12 16:44:50,363 [INFO] --- Starting processing for TX for year 2023 ---
# 2025-03-12 16:44:50,484 [ERROR] API call failed for op getSessionList with params {'state': 'TX', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,485 [WARNING] No session data for state TX
# 2025-03-12 16:44:50,485 [INFO] State TX: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,486 [INFO] --- Completed processing for TX for year 2023 ---
# 2025-03-12 16:44:50,487 [INFO] === Processing UT for year 2023 ===
# 2025-03-12 16:44:50,488 [INFO] --- Starting processing for UT for year 2023 ---
# 2025-03-12 16:44:50,611 [ERROR] API call failed for op getSessionList with params {'state': 'UT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,612 [WARNING] No session data for state UT
# 2025-03-12 16:44:50,613 [INFO] State UT: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,614 [INFO] --- Completed processing for UT for year 2023 ---
# 2025-03-12 16:44:50,615 [INFO] === Processing VT for year 2023 ===
# 2025-03-12 16:44:50,616 [INFO] --- Starting processing for VT for year 2023 ---
# 2025-03-12 16:44:50,738 [ERROR] API call failed for op getSessionList with params {'state': 'VT', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,739 [WARNING] No session data for state VT
# 2025-03-12 16:44:50,740 [INFO] State VT: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,741 [INFO] --- Completed processing for VT for year 2023 ---
# 2025-03-12 16:44:50,741 [INFO] === Processing VA for year 2023 ===
# 2025-03-12 16:44:50,742 [INFO] --- Starting processing for VA for year 2023 ---
# 2025-03-12 16:44:50,860 [ERROR] API call failed for op getSessionList with params {'state': 'VA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:50,861 [WARNING] No session data for state VA
# 2025-03-12 16:44:50,862 [INFO] State VA: Found 0 sessions for year 2023
# 2025-03-12 16:44:50,862 [INFO] --- Completed processing for VA for year 2023 ---
# 2025-03-12 16:44:50,863 [INFO] === Processing WA for year 2023 ===
# 2025-03-12 16:44:50,863 [INFO] --- Starting processing for WA for year 2023 ---
# 2025-03-12 16:44:51,005 [ERROR] API call failed for op getSessionList with params {'state': 'WA', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:51,006 [WARNING] No session data for state WA
# 2025-03-12 16:44:51,007 [INFO] State WA: Found 0 sessions for year 2023
# 2025-03-12 16:44:51,008 [INFO] --- Completed processing for WA for year 2023 ---
# 2025-03-12 16:44:51,009 [INFO] === Processing WV for year 2023 ===
# 2025-03-12 16:44:51,009 [INFO] --- Starting processing for WV for year 2023 ---
# 2025-03-12 16:44:51,129 [ERROR] API call failed for op getSessionList with params {'state': 'WV', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:51,130 [WARNING] No session data for state WV
# 2025-03-12 16:44:51,131 [INFO] State WV: Found 0 sessions for year 2023
# 2025-03-12 16:44:51,131 [INFO] --- Completed processing for WV for year 2023 ---
# 2025-03-12 16:44:51,132 [INFO] === Processing WI for year 2023 ===
# 2025-03-12 16:44:51,133 [INFO] --- Starting processing for WI for year 2023 ---
# 2025-03-12 16:44:51,252 [ERROR] API call failed for op getSessionList with params {'state': 'WI', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:51,253 [WARNING] No session data for state WI
# 2025-03-12 16:44:51,254 [INFO] State WI: Found 0 sessions for year 2023
# 2025-03-12 16:44:51,256 [INFO] --- Completed processing for WI for year 2023 ---
# 2025-03-12 16:44:51,256 [INFO] === Processing WY for year 2023 ===
# 2025-03-12 16:44:51,257 [INFO] --- Starting processing for WY for year 2023 ---
# 2025-03-12 16:44:51,378 [ERROR] API call failed for op getSessionList with params {'state': 'WY', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:51,379 [WARNING] No session data for state WY
# 2025-03-12 16:44:51,379 [INFO] State WY: Found 0 sessions for year 2023
# 2025-03-12 16:44:51,380 [INFO] --- Completed processing for WY for year 2023 ---
# 2025-03-12 16:44:51,380 [INFO] === Processing AL for year 2022 ===
# 2025-03-12 16:44:51,381 [INFO] --- Starting processing for AL for year 2022 ---
# 2025-03-12 16:44:51,502 [ERROR] API call failed for op getSessionList with params {'state': 'AL', 'key': 'c54a2cddb8d0e7b54de012389c3b0fda', 'op': 'getSessionList'}: {'status': 'ERROR', 'alert': {'message': 'API key has exceeded maximum query count for March 2025 (30,082 of 30,000); limit resets April 1st [Creating additional keys to bypass this limit will result in suspended access]', 'contact': {'email': 'api@legiscan.com', 'phone': '800-618-2750'}}}
# 2025-03-12 16:44:51,502 [WARNING] No session data for state AL
# 2025-03-12 16:44:51,503 [INFO] State AL: Found 0 sessions for year 2022
# 2025-03-12 16:44:51,503 [INFO] --- Completed processing for AL for year 2022 ---
# 2025-03-12 16:44:51,504 [INFO] === Processing AK for year 2022 ===
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[9], line 331
#     328             checkpoint = None
#     330 if __name__ == "__main__":
# --> 331     main()
#
# Cell In[9], line 326, in main()
#     324 for state in STATE_ABBREVIATIONS:
#     325     logging.info(f"=== Processing {state} for year {year} ===")
# --> 326     process_state_year(year, state, checkpoint=checkpoint)
#     327     # Reset checkpoint for next state/year combination
#     328     checkpoint = None
#
# Cell In[9], line 241, in process_state_year(year, state, checkpoint)
#     239 def process_state_year(year, state, checkpoint=None):
#     240     filename = f"legiscan_{state}_{year}.xlsx"
# --> 241     logging.info(f"--- Starting processing for {state} for year {year} ---")
#     242     sessions = get_session_list(state)
#     243     # Filter sessions by year using session_name or year boundaries
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:2148, in info(msg, *args, **kwargs)
#    2146 if len(root.handlers) == 0:
#    2147     basicConfig()
# -> 2148 root.info(msg, *args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1489, in Logger.info(self, msg, *args, **kwargs)
#    1480 """
#    1481 Log 'msg % args' with severity 'INFO'.
#    1482
#    (...)
#    1486 logger.info("Houston, we have a %s", "interesting problem", exc_info=1)
#    1487 """
#    1488 if self.isEnabledFor(INFO):
# -> 1489     self._log(INFO, msg, args, **kwargs)
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1634, in Logger._log(self, level, msg, args, exc_info, extra, stack_info, stacklevel)
#    1631         exc_info = sys.exc_info()
#    1632 record = self.makeRecord(self.name, level, fn, lno, msg, args,
#    1633                          exc_info, func, extra, sinfo)
# -> 1634 self.handle(record)
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1644, in Logger.handle(self, record)
#    1637 """
#    1638 Call the handlers for the specified record.
#    1639
#    1640 This method is used for unpickled records received from a socket, as
#    1641 well as those created locally. Logger-level filtering is applied.
#    1642 """
#    1643 if (not self.disabled) and self.filter(record):
# -> 1644     self.callHandlers(record)
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1706, in Logger.callHandlers(self, record)
#    1704     found = found + 1
#    1705     if record.levelno >= hdlr.level:
# -> 1706         hdlr.handle(record)
#    1707 if not c.propagate:
#    1708     c = None    #break out
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:978, in Handler.handle(self, record)
#     976 self.acquire()
#     977 try:
# --> 978     self.emit(record)
#     979 finally:
#     980     self.release()
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1230, in FileHandler.emit(self, record)
#    1228         self.stream = self._open()
#    1229 if self.stream:
# -> 1230     StreamHandler.emit(self, record)
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1114, in StreamHandler.emit(self, record)
#    1112     # issue 35046: merged two stream.writes into one.
#    1113     stream.write(msg + self.terminator)
# -> 1114     self.flush()
#    1115 except RecursionError:  # See issue 36272
#    1116     raise
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:1096, in StreamHandler.flush(self)
#    1094         self.stream.flush()
#    1095 finally:
# -> 1096     self.release()
#
# File ~/miniconda3/lib/python3.11/logging/__init__.py:929, in Handler.release(self)
#     926     if self.lock:
#     927         self.lock.acquire()
# --> 929 def release(self):
#     930     """
#     931     Release the I/O thread lock.
#     932     """
#     933     if self.lock:
#
# KeyboardInterrupt:
